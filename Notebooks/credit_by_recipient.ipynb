# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandasql import sqldf

# %% [raw]
# For this notebook, I want to understand the types of carbon projects and the type of credits they are generating, and what types of credits different companies are investing in.

# %%
verra_df = pd.read_csv('../Data/VCU_Registry_Result_V2_5.2.22.csv')

# %%
verra_df.head()
# Out:
#   Issuance Date Sustainable Development Goals Vintage Start Vintage End    ID  \
# 0    29/04/2022                           NaN    01/11/2020  31/12/2020   682
# 1    29/04/2022                           NaN    01/01/2021  31/08/2021   682
# 2    29/04/2022                           NaN    28/08/2020  31/12/2020  1319
# 3    29/04/2022                           NaN    01/01/2021  30/09/2021  1319
# 4    29/04/2022                           NaN    01/01/2016  31/12/2016  1408
#
#                                                 Name     Country  \
# 0         Wind Power Project at Anthiyur, Tamil Nadu       India
# 1         Wind Power Project at Anthiyur, Tamil Nadu       India
# 2  Small-Scale Hydropower Project Sahanivotry In ...  Madagascar
# 3  Small-Scale Hydropower Project Sahanivotry In ...  Madagascar
# 4                         Chyulu Hills REDD+ Project       Kenya
#
#                                         Project Type Methodology  \
# 0  Energy industries (renewable/non-renewable sou...    AMS-I.D.
# 1  Energy industries (renewable/non-renewable sou...    AMS-I.D.
# 2  Energy industries (renewable/non-renewable sou...     ACM0002
# 3  Energy industries (renewable/non-renewable sou...     ACM0002
# 4            Agriculture Forestry and Other Land Use      VM0009
#
#    Total Vintage Quantity  Quantity Issued  \
# 0                     663              663
# 1                   22486            22486
# 2                    4773             4773
# 3                   20747            20747
# 4                  617707            70000
#
#                                        Serial Number  \
# 0  12990-464677897-464678559-VCS-VCU-997-VER-IN-1...
# 1  12991-464678560-464701045-VCS-VCU-997-VER-IN-1...
# 2  12992-464701046-464705818-VCS-VCU-997-VER-MG-1...
# 3  12993-464705819-464726565-VCS-VCU-997-VER-MG-1...
# 4  12994-464726566-464796565-VCS-VCU-263-VER-KE-1...
#
#                            Additional Certifications  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  CCB-Biodiversity Gold; CCB-Climate Gold; CCB-C...
#
#   Retirement/Cancellation Date Retirement Beneficiary Retirement Reason  \
# 0                          NaN                    NaN               NaN
# 1                          NaN                    NaN               NaN
# 2                          NaN                    NaN               NaN
# 3                          NaN                    NaN               NaN
# 4                          NaN                    NaN               NaN
#
#   Retirement Details
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %% [markdown]
# First, cleaning column names

# %%
#getting rid of spaces and slashes
verra_df.columns = verra_df.columns.str.replace(' ','_')

verra_df.columns = verra_df.columns.str.lower()

# %%
verra_df.columns = verra_df.columns.str.replace('/','_')

# %%
verra_df.columns
# Out:
# Index(['issuance_date', 'sustainable_development_goals', 'vintage_start',
#        'vintage_end', 'id', 'name', 'country', 'project_type', 'methodology',
#        'total_vintage_quantity', 'quantity_issued', 'serial_number',
#        'additional_certifications', 'retirement_cancellation_date',
#        'retirement_beneficiary', 'retirement_reason', 'retirement_details'],
#       dtype='object')

# %% [markdown]
# Looking for all of the different project types

# %%
pd.DataFrame(verra_df['project_type'].value_counts())
# Out:
#                                                     project_type
# Agriculture Forestry and Other Land Use                    98508
# Energy industries (renewable/non-renewable sour...         51547
# Waste handling and disposal                                 2344
# Fugitive emissions from fuels (solid, oil and gas)          1952
# Mining/mineral production                                   1245
# Energy demand                                                906
# Energy industries (renewable/non-renewable sour...           799
# Manufacturing industries                                     785
# Chemical industry                                            755
# Energy industries (renewable/non-renewable sour...           698
# Construction; Energy industries (renewable/non-...           254
# Fugitive emissions from fuels (solid, oil and g...           164
# Energy demand; Waste handling and disposal                   141
# Energy demand; Energy industries (renewable/non...           136
# Fugitive emissions from production and consumpt...           119
# Chemical industry; Energy industries (renewable...            92
# Metal production                                              72
# Energy distribution                                           63
# Transport                                                     54
# Livestock, enteric fermentation, and manure man...            48
# Energy industries (renewable/non-renewable sour...            23
# Energy industries (renewable/non-renewable sour...             2
# Agriculture Forestry and Other Land Use; Energy...             1

# %% [raw]
# Some Projects have 2 different types associated with them. Get rid of projects with multiple Project Types.

# %%
pysqldf = lambda q: sqldf(q, globals())

# %%
#Pulling a list of IDs for projects that have multiple project types
q = """
SELECT
    id
FROM
    verra_df
WHERE
    project_type LIKE '%;%'
     """

# %%
results = pysqldf(q)

# %%
pd.set_option('display.max_colwidth', None)

# %%
results
# Out:
#         id
# 0     2302
# 1     2302
# 2     2302
# 3     2291
# 4     2291
# ...    ...
# 2305   127
# 2306   127
# 2307   108
# 2308   108
# 2309   108
#
# [2310 rows x 1 columns]

# %%
results.shape
# Out:
# (2310, 1)

# %%
#Creating a dataframe that excludes any IDed projects with multiple project types
x = """
SELECT
    *
FROM
    verra_df AS vf
    LEFT JOIN results AS rt
    ON vf.id = rt.id
WHERE
    vf.id NOT IN results
     """

# %%
verra_df_type = verra_df.copy

# %%
#applying the query to update the dataframe
verra_df_type = pysqldf(x)

# %% [markdown]
# Confirm the change worked and count the values of each type of project

# %%
#removing the additional ID column so I can use ID as a unique identifier
verra_df_type = verra_df_type.iloc[: , :-1]

verra_df_type.head()
# Out:
#   issuance_date sustainable_development_goals vintage_start vintage_end    id  \
# 0    29/04/2022                          None    01/11/2020  31/12/2020   682
# 1    29/04/2022                          None    01/01/2021  31/08/2021   682
# 2    29/04/2022                          None    28/08/2020  31/12/2020  1319
# 3    29/04/2022                          None    01/01/2021  30/09/2021  1319
# 4    29/04/2022                          None    01/01/2016  31/12/2016  1408
#
#                                                         name     country  \
# 0                 Wind Power Project at Anthiyur, Tamil Nadu       India
# 1                 Wind Power Project at Anthiyur, Tamil Nadu       India
# 2  Small-Scale Hydropower Project Sahanivotry In Madagascar.  Madagascar
# 3  Small-Scale Hydropower Project Sahanivotry In Madagascar.  Madagascar
# 4                                 Chyulu Hills REDD+ Project       Kenya
#
#                                           project_type methodology  \
# 0  Energy industries (renewable/non-renewable sources)    AMS-I.D.
# 1  Energy industries (renewable/non-renewable sources)    AMS-I.D.
# 2  Energy industries (renewable/non-renewable sources)     ACM0002
# 3  Energy industries (renewable/non-renewable sources)     ACM0002
# 4              Agriculture Forestry and Other Land Use      VM0009
#
#    total_vintage_quantity  quantity_issued  \
# 0                     663              663
# 1                   22486            22486
# 2                    4773             4773
# 3                   20747            20747
# 4                  617707            70000
#
#                                                               serial_number  \
# 0    12990-464677897-464678559-VCS-VCU-997-VER-IN-1-682-01112020-31122020-0
# 1    12991-464678560-464701045-VCS-VCU-997-VER-IN-1-682-01012021-31082021-0
# 2   12992-464701046-464705818-VCS-VCU-997-VER-MG-1-1319-28082020-31122020-0
# 3   12993-464705819-464726565-VCS-VCU-997-VER-MG-1-1319-01012021-30092021-0
# 4  12994-464726566-464796565-VCS-VCU-263-VER-KE-14-1408-01012016-31122016-1
#
#                                                additional_certifications  \
# 0                                                                   None
# 1                                                                   None
# 2                                                                   None
# 3                                                                   None
# 4  CCB-Biodiversity Gold; CCB-Climate Gold; CCB-Community Gold; CCB-Gold
#
#   retirement_cancellation_date retirement_beneficiary retirement_reason  \
# 0                         None                   None              None
# 1                         None                   None              None
# 2                         None                   None              None
# 3                         None                   None              None
# 4                         None                   None              None
#
#   retirement_details
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None

# %%
verra_df_type.project_type.value_counts()
# Out:
# Agriculture Forestry and Other Land Use                                                       98508
# Energy industries (renewable/non-renewable sources)                                           51547
# Waste handling and disposal                                                                    2344
# Fugitive emissions from fuels (solid, oil and gas)                                             1952
# Mining/mineral production                                                                      1245
# Energy demand                                                                                   906
# Manufacturing industries                                                                        785
# Chemical industry                                                                               755
# Fugitive emissions from production and consumption of halocarbons and sulphur hexafluoride      119
# Metal production                                                                                 72
# Energy distribution                                                                              63
# Transport                                                                                        54
# Livestock, enteric fermentation, and manure management                                           48
# Name: project_type, dtype: int64

# %% [markdown]
# With this list of projects, lets simplify the types of projects into four categories:
# - nature-based credits (AFOLU)
# - nature-based sequestration avoidance or reduction of emissions such as methane from landfills
# - technology-based credits from energy generation - renewable/non-renewable offsets
# - technology-based avoidance through efficiencies/retrofits
#
# While amended to better fit data, original source for 4 categories:https://www.mckinsey.com/business-functions/sustainability/our-insights/a-blueprint-for-scaling-voluntary-carbon-markets-to-meet-the-climate-challenge

# %%
#building a dictionary to map onto existing project types to generalize the data for visualization
typedict= {
    'Agriculture Forestry and Other Land Use':'AFOLU',
    'Livestock, enteric fermentation, and manure management':'Other nature-based sequestration, avoidance, or reduction',
    'Energy industries (renewable/non-renewable sources)':'renewable/non-renewable offsets',
    'Waste handling and disposal':'Avoided emissions via efficiencies/retrofits',
    'Fugitive emissions from fuels (solid, oil and gas)':'Avoided emissions via efficiencies/retrofits',
    'Mining/mineral production':'Avoided emissions via efficiencies/retrofits',
    'Manufacturing industries':'Avoided emissions via efficiencies/retrofits',
    'Chemical industry':'Avoided emissions via efficiencies/retrofits',
    'Fugitive emissions from production and consumption of halocarbons and sulphur hexafluoride':'Avoided emissions via efficiencies/retrofits',
    'Metal production':'Avoided emissions via efficiencies/retrofits',
    'Energy demand':'Avoided emissions via efficiencies/retrofits',
    'Energy distribution':'Avoided emissions via efficiencies/retrofits',
    'Transport':'Avoided emissions via efficiencies/retrofits',
}

# %%
#mapping dictionary
verra_df_type['project_type'] = verra_df_type['project_type'].map(typedict)

# %%
verra_df_type.project_type.value_counts()
# Out:
# AFOLU                                                        98508
# renewable/non-renewable offsets                              51547
# Avoided emissions via efficiencies/retrofits                  8295
# Other nature-based sequestration, avoidance, or reduction       48
# Name: project_type, dtype: int64

# %% [markdown]
# Now that the data has 4 easy to use categories, lets group the volume of credits by beneficiary of the retirement of the credit, and the type of credit to see who is buying what.

# %%
org_by_type = verra_df_type.copy()

# %%
org_by_type.head()
# Out:
#   issuance_date sustainable_development_goals vintage_start vintage_end    id  \
# 0    29/04/2022                          None    01/11/2020  31/12/2020   682
# 1    29/04/2022                          None    01/01/2021  31/08/2021   682
# 2    29/04/2022                          None    28/08/2020  31/12/2020  1319
# 3    29/04/2022                          None    01/01/2021  30/09/2021  1319
# 4    29/04/2022                          None    01/01/2016  31/12/2016  1408
#
#                                                         name     country  \
# 0                 Wind Power Project at Anthiyur, Tamil Nadu       India
# 1                 Wind Power Project at Anthiyur, Tamil Nadu       India
# 2  Small-Scale Hydropower Project Sahanivotry In Madagascar.  Madagascar
# 3  Small-Scale Hydropower Project Sahanivotry In Madagascar.  Madagascar
# 4                                 Chyulu Hills REDD+ Project       Kenya
#
#                       project_type methodology  total_vintage_quantity  \
# 0  renewable/non-renewable offsets    AMS-I.D.                     663
# 1  renewable/non-renewable offsets    AMS-I.D.                   22486
# 2  renewable/non-renewable offsets     ACM0002                    4773
# 3  renewable/non-renewable offsets     ACM0002                   20747
# 4                            AFOLU      VM0009                  617707
#
#    quantity_issued  \
# 0              663
# 1            22486
# 2             4773
# 3            20747
# 4            70000
#
#                                                               serial_number  \
# 0    12990-464677897-464678559-VCS-VCU-997-VER-IN-1-682-01112020-31122020-0
# 1    12991-464678560-464701045-VCS-VCU-997-VER-IN-1-682-01012021-31082021-0
# 2   12992-464701046-464705818-VCS-VCU-997-VER-MG-1-1319-28082020-31122020-0
# 3   12993-464705819-464726565-VCS-VCU-997-VER-MG-1-1319-01012021-30092021-0
# 4  12994-464726566-464796565-VCS-VCU-263-VER-KE-14-1408-01012016-31122016-1
#
#                                                additional_certifications  \
# 0                                                                   None
# 1                                                                   None
# 2                                                                   None
# 3                                                                   None
# 4  CCB-Biodiversity Gold; CCB-Climate Gold; CCB-Community Gold; CCB-Gold
#
#   retirement_cancellation_date retirement_beneficiary retirement_reason  \
# 0                         None                   None              None
# 1                         None                   None              None
# 2                         None                   None              None
# 3                         None                   None              None
# 4                         None                   None              None
#
#   retirement_details
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None

# %% [markdown]
# Adding a column to sum up all credits retired by a given recipient - not cleaning for accessory words

# %%
#new query builds a dataframe that only includes ID, Company, Project Type (generalized)
# The number of credits retired under the identified company, total credits generated by
#that project, and the issuance/retirement date.

#The subquery Sums up the total credits issued for a project
y = """
SELECT
    fv.id,
    retirement_beneficiary,
    project_type,
    fv.quantity_issued AS credit_type_issued,
    vf.total_project_credits AS project_credits,
    issuance_date,
    retirement_cancellation_date
FROM
    verra_df_type AS fv
    INNER JOIN (
        SELECT
            id,
            SUM(quantity_issued) AS total_project_credits
        FROM
            verra_df_type
        GROUP BY
            id
        ) AS vf
        ON
            fv.id = vf.id
WHERE
    retirement_beneficiary NOT NULL
     """

# %%
org_by_type_clean = verra_df_type.copy()

# %%
# new dataframe built on the above query
org_by_type_clean = pysqldf(y)

# %%
org_by_type_clean.head(15)
# Out:
#       id                       retirement_beneficiary  \
# 0    487  Renewable World on behalf of Octopus Energy
# 1   1964                                      Conapto
# 2    487  Renewable World on behalf of Octopus Energy
# 3    487  Renewable World on behalf of Octopus Energy
# 4    487  Renewable World on behalf of Octopus Energy
# 5    487  Renewable World on behalf of Octopus Energy
# 6    934           Takeda Pharmaceutical Company Ltd.
# 7    868                           Engie Energía Perú
# 8    487  Renewable World on behalf of Octopus Energy
# 9    487  Renewable World on behalf of Octopus Energy
# 10   487             Renewable World on behalf of HFW
# 11   902                                            _
# 12  1740                                            _
# 13  1477                            World Surf League
# 14  1975                                            _
#
#                        project_type  credit_type_issued  project_credits  \
# 0   renewable/non-renewable offsets                 776          3474110
# 1   renewable/non-renewable offsets                 138            90638
# 2   renewable/non-renewable offsets               21239          3474110
# 3   renewable/non-renewable offsets               52463          3474110
# 4   renewable/non-renewable offsets                 233          3474110
# 5   renewable/non-renewable offsets                5281          3474110
# 6                             AFOLU               50000         26629250
# 7                             AFOLU                 250         11702444
# 8   renewable/non-renewable offsets                4000          3474110
# 9   renewable/non-renewable offsets                1175          3474110
# 10  renewable/non-renewable offsets                4108          3474110
# 11                            AFOLU               18750         21591936
# 12                            AFOLU                1000           248365
# 13                            AFOLU                 550         38581777
# 14  renewable/non-renewable offsets                9905            40585
#
#    issuance_date retirement_cancellation_date
# 0     13/04/2022                   13/04/2022
# 1     11/04/2022                   22/04/2022
# 2     07/04/2022                   14/04/2022
# 3     07/04/2022                   14/04/2022
# 4     07/04/2022                   14/04/2022
# 5     07/04/2022                   13/04/2022
# 6     31/03/2022                   29/04/2022
# 7     30/03/2022                   22/04/2022
# 8     28/03/2022                   13/04/2022
# 9     28/03/2022                   13/04/2022
# 10    28/03/2022                   13/04/2022
# 11    28/03/2022                   31/03/2022
# 12    28/03/2022                   21/04/2022
# 13    24/03/2022                   05/04/2022
# 14    23/03/2022                   01/04/2022

# %%
org_by_type_clean.shape
# Out:
# (44052, 7)

# %%
#shrinking the dataframe to only incldue company,type,and issued credits
test1 = org_by_type_clean.iloc[:, 1:4]

# %%
#group by both beneficiary and type so that all credits of that type are summed up for a given
#company
test1 = test1.groupby(['retirement_beneficiary', 'project_type']).sum()

# %%
#sort list to see largest companies/types of credits
test1.sort_values(by='credit_type_issued',
                 ascending=False,
                 inplace=True)

test1.head(25)
# Out:
#                                                                                          credit_type_issued
# retirement_beneficiary                                  project_type
# Shell                                                   AFOLU                                       7928999
# Delta Air Lines                                         renewable/non-renewable offsets             6442460
# PRIMAX COLOMBIA S.A identificada con Nit: 860.002.554-8 AFOLU                                       5250000
# DL                                                      AFOLU                                       5177451
# Greenchoice                                             AFOLU                                       4714084
# GP-2                                                    renewable/non-renewable offsets             3580868
# Eni Upstream                                            AFOLU                                       3485945
# Telstra Corporation Limited                             renewable/non-renewable offsets             3466062
# Delta Air Lines                                         AFOLU                                       2646446
# DL                                                      renewable/non-renewable offsets             2624965
# AUDI AG                                                 AFOLU                                       2624720
# _                                                       renewable/non-renewable offsets             2275155
#                                                         AFOLU                                       2158380
# DPDgroup                                                renewable/non-renewable offsets             2043753
# Volkswagen Marke Pkw                                    AFOLU                                       2036155
# CHEVRON PETROLEUM COMPANY                               AFOLU                                       1920236
# Gucci                                                   AFOLU                                       1800010
# Takeda Pharmaceutical Company                           AFOLU                                       1650000
# The Boeing Company                                      renewable/non-renewable offsets             1624241
# Takeda Pharmaceutical Company                           renewable/non-renewable offsets             1573137
# Interface, Inc.                                         renewable/non-renewable offsets             1453647
# 0xAf529400FF068AFbdc907c699B9184a4381481B0              renewable/non-renewable offsets             1370419
# Brisbane City Council                                   renewable/non-renewable offsets             1320097
# GP-4                                                    renewable/non-renewable offsets             1299726
# 0xE519B28E8F96e229498F15bb2DA4eC0e942f688F              renewable/non-renewable offsets             1190818

# %%
#reset the index so I can manipulate based on company and type
test2 = test1.reset_index()

# %%
test2.head(25)
# Out:
#                                      retirement_beneficiary  \
# 0                                                     Shell
# 1                                           Delta Air Lines
# 2   PRIMAX COLOMBIA S.A identificada con Nit: 860.002.554-8
# 3                                                        DL
# 4                                               Greenchoice
# 5                                                      GP-2
# 6                                              Eni Upstream
# 7                               Telstra Corporation Limited
# 8                                           Delta Air Lines
# 9                                                        DL
# 10                                                  AUDI AG
# 11                                                        _
# 12                                                        _
# 13                                                 DPDgroup
# 14                                     Volkswagen Marke Pkw
# 15                                CHEVRON PETROLEUM COMPANY
# 16                                                    Gucci
# 17                            Takeda Pharmaceutical Company
# 18                                       The Boeing Company
# 19                            Takeda Pharmaceutical Company
# 20                                          Interface, Inc.
# 21               0xAf529400FF068AFbdc907c699B9184a4381481B0
# 22                                    Brisbane City Council
# 23                                                     GP-4
# 24               0xE519B28E8F96e229498F15bb2DA4eC0e942f688F
#
#                        project_type  credit_type_issued
# 0                             AFOLU             7928999
# 1   renewable/non-renewable offsets             6442460
# 2                             AFOLU             5250000
# 3                             AFOLU             5177451
# 4                             AFOLU             4714084
# 5   renewable/non-renewable offsets             3580868
# 6                             AFOLU             3485945
# 7   renewable/non-renewable offsets             3466062
# 8                             AFOLU             2646446
# 9   renewable/non-renewable offsets             2624965
# 10                            AFOLU             2624720
# 11  renewable/non-renewable offsets             2275155
# 12                            AFOLU             2158380
# 13  renewable/non-renewable offsets             2043753
# 14                            AFOLU             2036155
# 15                            AFOLU             1920236
# 16                            AFOLU             1800010
# 17                            AFOLU             1650000
# 18  renewable/non-renewable offsets             1624241
# 19  renewable/non-renewable offsets             1573137
# 20  renewable/non-renewable offsets             1453647
# 21  renewable/non-renewable offsets             1370419
# 22  renewable/non-renewable offsets             1320097
# 23  renewable/non-renewable offsets             1299726
# 24  renewable/non-renewable offsets             1190818

# %%
test2.shape
# Out:
# (24471, 3)

# %%
#checking to see if the biggest buyer has bought different types (what I want to stack in a bar chart)
test2.loc[test2['retirement_beneficiary'] == 'Delta Air Lines']
# Out:
#     retirement_beneficiary  \
# 1          Delta Air Lines
# 8          Delta Air Lines
# 194        Delta Air Lines
#
#                                                   project_type  \
# 1                              renewable/non-renewable offsets
# 8                                                        AFOLU
# 194  Other nature-based sequestration, avoidance, or reduction
#
#      credit_type_issued
# 1               6442460
# 8               2646446
# 194              166073

# %%
#pivot the type of credit so that there is only one record (row) per company.
test3 = test2.pivot(index='retirement_beneficiary', columns='project_type', values='credit_type_issued')

test3
# Out:
# project_type                                                                                             AFOLU  \
# retirement_beneficiary
#  Brokers Environmental Pty Ltd.                                                                            NaN
#  Dairong Jing                                                                                              NaN
#  Jianmei Zhong                                                                                             NaN
#  Jiarong Jin                                                                                               NaN
#  Liangxian Dai                                                                                             NaN
# ...                                                                                                        ...
# Şen Lpg Akaryakıt İnş.Gıda . San.Tic.Ltd.Şti                                                               NaN
# ŠKODA AUTO a.s.                                                                                            NaN
# “Resulting from manufacturing at Husqvarna manufacturing sites at Aycliffe, Nashville and Orangeburg”      NaN
# “Resulting from the production, use and end-of-life of robotic lawn mowers of Husqvarna”                   NaN
# “Retired on behalf of Offset Earth Limited”                                                            15000.0
#
# project_type                                                                                           Avoided emissions via efficiencies/retrofits  \
# retirement_beneficiary
#  Brokers Environmental Pty Ltd.                                                                                                                20.0
#  Dairong Jing                                                                                                                                   NaN
#  Jianmei Zhong                                                                                                                                  NaN
#  Jiarong Jin                                                                                                                                    NaN
#  Liangxian Dai                                                                                                                                  NaN
# ...                                                                                                                                             ...
# Şen Lpg Akaryakıt İnş.Gıda . San.Tic.Ltd.Şti                                                                                                    NaN
# ŠKODA AUTO a.s.                                                                                                                                 NaN
# “Resulting from manufacturing at Husqvarna manufacturing sites at Aycliffe, Nashville and Orangeburg”                                           NaN
# “Resulting from the production, use and end-of-life of robotic lawn mowers of Husqvarna”                                                        NaN
# “Retired on behalf of Offset Earth Limited”                                                                                                     NaN
#
# project_type                                                                                           Other nature-based sequestration, avoidance, or reduction  \
# retirement_beneficiary
#  Brokers Environmental Pty Ltd.                                                                                                                              NaN
#  Dairong Jing                                                                                                                                                NaN
#  Jianmei Zhong                                                                                                                                               NaN
#  Jiarong Jin                                                                                                                                                 NaN
#  Liangxian Dai                                                                                                                                               NaN
# ...                                                                                                                                                          ...
# Şen Lpg Akaryakıt İnş.Gıda . San.Tic.Ltd.Şti                                                                                                                 NaN
# ŠKODA AUTO a.s.                                                                                                                                              NaN
# “Resulting from manufacturing at Husqvarna manufacturing sites at Aycliffe, Nashville and Orangeburg”                                                        NaN
# “Resulting from the production, use and end-of-life of robotic lawn mowers of Husqvarna”                                                                     NaN
# “Retired on behalf of Offset Earth Limited”                                                                                                                  NaN
#
# project_type                                                                                           renewable/non-renewable offsets
# retirement_beneficiary
#  Brokers Environmental Pty Ltd.                                                                                                    NaN
#  Dairong Jing                                                                                                                      5.0
#  Jianmei Zhong                                                                                                                     5.0
#  Jiarong Jin                                                                                                                       5.0
#  Liangxian Dai                                                                                                                     5.0
# ...                                                                                                                                ...
# Şen Lpg Akaryakıt İnş.Gıda . San.Tic.Ltd.Şti                                                                                      50.0
# ŠKODA AUTO a.s.                                                                                                                  210.0
# “Resulting from manufacturing at Husqvarna manufacturing sites at Aycliffe, Nashville and Orangeburg”                           1450.0
# “Resulting from the production, use and end-of-life of robotic lawn mowers of Husqvarna”                                        6000.0
# “Retired on behalf of Offset Earth Limited”                                                                                        NaN
#
# [23437 rows x 4 columns]

# %%
#reset the index again so the Company can be used
test4 = test3.reset_index()

# %%
#fill NaN cells with 0
test4 = test4.fillna(0)

# %%
#confirm that the summed values per credit type are still in the dataframe
test4.sort_values(by='AFOLU',
                 ascending=False)
# Out:
# project_type                                   retirement_beneficiary  \
# 19611                                                           Shell
# 16207         PRIMAX COLOMBIA S.A identificada con Nit: 860.002.554-8
# 5775                                                               DL
# 9388                                                      Greenchoice
# 7231                                                     Eni Upstream
# ...                                                               ...
# 10408                                 ISGEC HEAVY ENGINEERING LIMITED
# 10409                                 ISHVERLAL MADANLAL & CO PVT LTD
# 10410                                       ISHWAR BUSINESS SOLUTIONS
# 10411                                           ISKY CHEMICALS CO LTD
# 0                                      Brokers Environmental Pty Ltd.
#
# project_type      AFOLU  Avoided emissions via efficiencies/retrofits  \
# 19611         7928999.0                                           0.0
# 16207         5250000.0                                           0.0
# 5775          5177451.0                                      480825.0
# 9388          4714084.0                                           0.0
# 7231          3485945.0                                           0.0
# ...                 ...                                           ...
# 10408               0.0                                           0.0
# 10409               0.0                                           0.0
# 10410               0.0                                           0.0
# 10411               0.0                                           0.0
# 0                   0.0                                          20.0
#
# project_type  Other nature-based sequestration, avoidance, or reduction  \
# 19611                                                               0.0
# 16207                                                               0.0
# 5775                                                                0.0
# 9388                                                                0.0
# 7231                                                                0.0
# ...                                                                 ...
# 10408                                                               0.0
# 10409                                                               0.0
# 10410                                                               0.0
# 10411                                                               0.0
# 0                                                                   0.0
#
# project_type  renewable/non-renewable offsets
# 19611                                     0.0
# 16207                                     0.0
# 5775                                2624965.0
# 9388                                   2437.0
# 7231                                      0.0
# ...                                       ...
# 10408                                     2.0
# 10409                                     2.0
# 10410                                     1.0
# 10411                                     1.0
# 0                                         0.0
#
# [23437 rows x 5 columns]

# %%
#sort by the top 2 largest credit types to bring the largest buyers
#of credits to the top of the dataframe
test5 = test4.sort_values(['AFOLU', 'renewable/non-renewable offsets'],
              ascending = [False, False])

# %%
#confirm
test5.head(15)
# Out:
# project_type                                   retirement_beneficiary  \
# 19611                                                           Shell
# 16207         PRIMAX COLOMBIA S.A identificada con Nit: 860.002.554-8
# 5775                                                               DL
# 9388                                                      Greenchoice
# 7231                                                     Eni Upstream
# 6132                                                  Delta Air Lines
# 1046                                                          AUDI AG
# 23038                                                               _
# 21860                                            Volkswagen Marke Pkw
# 3551                                        CHEVRON PETROLEUM COMPANY
# 9469                                                            Gucci
# 20711                                   Takeda Pharmaceutical Company
# 16575                PetroChina International Company Limited (“PCI”)
# 4366                                                           Chanel
# 9471                                                 Guccio Gucci Spa
#
# project_type      AFOLU  Avoided emissions via efficiencies/retrofits  \
# 19611         7928999.0                                           0.0
# 16207         5250000.0                                           0.0
# 5775          5177451.0                                      480825.0
# 9388          4714084.0                                           0.0
# 7231          3485945.0                                           0.0
# 6132          2646446.0                                           0.0
# 1046          2624720.0                                           0.0
# 23038         2158380.0                                      158128.0
# 21860         2036155.0                                           0.0
# 3551          1920236.0                                        1978.0
# 9469          1800010.0                                           0.0
# 20711         1650000.0                                        8831.0
# 16575         1102312.0                                           0.0
# 4366          1030000.0                                           0.0
# 9471          1000000.0                                           0.0
#
# project_type  Other nature-based sequestration, avoidance, or reduction  \
# 19611                                                               0.0
# 16207                                                               0.0
# 5775                                                                0.0
# 9388                                                                0.0
# 7231                                                                0.0
# 6132                                                           166073.0
# 1046                                                                0.0
# 23038                                                               0.0
# 21860                                                               0.0
# 3551                                                                0.0
# 9469                                                                0.0
# 20711                                                               0.0
# 16575                                                               0.0
# 4366                                                                0.0
# 9471                                                                0.0
#
# project_type  renewable/non-renewable offsets
# 19611                                     0.0
# 16207                                     0.0
# 5775                                2624965.0
# 9388                                   2437.0
# 7231                                      0.0
# 6132                                6442460.0
# 1046                                 361858.0
# 23038                               2275155.0
# 21860                                320101.0
# 3551                                  41971.0
# 9469                                      0.0
# 20711                               1573137.0
# 16575                                     0.0
# 4366                                      0.0
# 9471                                      0.0

# %%
#cut to the top 10 companies
test6 = test5[:11]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-16fa8748e1e9> in <module>
#       2 test6 = test5[:11]
#       3
# ----> 4 test6.index()
#
# TypeError: 'Int64Index' object is not callable

# %%
test6 = test6.sort_index(key=test6.sum(1, numeric_only=True).get)

# %%
sns.set(style="darkgrid")

sns.color_palette("rocket")

sns.set(rc = {'figure.figsize':(15,10)})

#create stacked bar chart
plot = test6.set_index('retirement_beneficiary').plot(kind='bar', stacked=True)

#add overall title
plt.title('Company Credits by Type', fontsize=16)

#update y axis from scientific notation
plot.ticklabel_format(style='plain', scilimits=(0,20), axis='y')
ylabels = ['{:,.0f}'.format(y) + ' MM' for y in plot.get_yticks()/1000000]
plot.set_yticklabels(ylabels)

#add axis titles
plt.xlabel('Companies')
plt.ylabel('Number of Credits Retired')
# Out:
# <ipython-input-85-763869f90432>:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plot.set_yticklabels(ylabels)
# Text(0, 0.5, 'Number of Credits Retired')

# %%
sns.set(style='white')

#create stacked bar chart
test6.set_index('retirement_beneficiary').plot(kind='bar', stacked=True, color=['steelblue', 'red', 'green', 'orange'])

#add overall title
plt.title('Company Credits by Type', fontsize=16)

#add axis titles
plt.xlabel('Companies')
plt.ylabel('Number of Credits Retired')
# Out:
# Text(0, 0.5, 'Number of Credits Retired')
